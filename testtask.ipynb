# %%
import numpy as np
import matplotlib.pyplot as plt 
import datetime
import pandas as pd  
import seaborn as sns

# %%
# TODO  Assign it to a variable called data and replace the first 3 columns by a proper datetime index

# %%
data = pd.read_csv('weather_dataset.data', sep="\s+", decimal=",")
data_test = pd.read_csv('weather_dataset.data', sep="\s+")

# %%
data
# Out:
#       Yr  Mo  Dy   loc1   loc2   loc3   loc4   loc5   loc6   loc7   loc8  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#        loc9  loc10  loc11  loc12
# 0     10.83  12.58  18.50  15.04
# ...

# %%
data[['Yr','Mo','Dy']]=data[['Yr','Mo','Dy']].astype(str)
data['Date'] = '19'+data['Yr']+data['Mo']+data['Dy']
data['Date']=pd.to_datetime(data['Date'], format='%Y%m%d')
data = data.set_index('Date')
data = data.drop(['Yr','Mo','Dy'],axis=1)

# %%
data.head()
# Out:
#              loc1   loc2   loc3  loc4   loc5  loc6   loc7  loc8   loc9  loc10  \
# Date
# 1961-01-04  10.58   6.63  11.75  4.58   4.54  2.88   8.63  1.79   5.83   5.88
# 1961-01-05  13.33  13.25  11.42  6.17  10.71  8.21  11.92  6.54  10.92  10.34
# 1961-01-06  13.21   8.12   9.96  6.67   5.37  4.50  10.67  4.42   7.17   7.50
# 1961-01-07  13.50  14.29   9.50  4.96  12.29  8.33   9.17  9.29   7.58   7.96
# 1961-01-08  10.96   9.75   7.62  5.91   9.62  7.29  14.29  7.62   9.25  10.46
#
#             loc11  loc12
# Date
# 1961-01-04   5.46  10.88
# 1961-01-05  12.92  11.83
# 1961-01-06   8.12  13.17
# 1961-01-07  13.96  13.79
# 1961-01-08  16.62  16.46

# %%
# TODO Check if everything is okay with the data. Create functions to delete/fix rows with strange cases and apply them

# %%
data.isna().sum() # пустых значений по столбцам
# Out:
# loc1     6
# loc2     3
# loc3     3
# loc4     5
# loc5     2
# loc6     0
# loc7     3
# loc8     2
# loc9     4
# loc10    1
# loc11    0
# loc12    4
# dtype: int64

# %%
data.isna().sum().sum() # всього порожніх значень
# Out:
# 33

# %%
data = data.apply(pd.to_numeric, errors='coerce')# всі значення, які не можна змінити на float64 замінили на NaN

# %%
data.info() # всього у нас 6574 рядків, подивившись на кількість порожніх (там могли бути або порожні значення, або які не можна змінити на float64)
            # ми бачимо, що їх не багато, тому ці рядки можна видалити
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6574 entries, 1961-01-01 to 1978-12-31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   loc1    6568 non-null   float64
#  1   loc2    6571 non-null   float64
#  2   loc3    6571 non-null   float64
#  3   loc4    6568 non-null   float64
#  4   loc5    6571 non-null   float64
#  5   loc6    6574 non-null   float64
#  6   loc7    6571 non-null   float64
#  7   loc8    6572 non-null   float64
#  8   loc9    6569 non-null   float64
#  9   loc10   6572 non-null   float64
#  10  loc11   6574 non-null   float64
#  11  loc12   6569 non-null   float64
# dtypes: float64(12)
# memory usage: 667.7 KB

# %%
data.isna().sum()# порожніх значень по стовпцях після заміни
# Out:
# loc1     6
# loc2     3
# loc3     3
# loc4     6
# loc5     3
# loc6     0
# loc7     3
# loc8     2
# loc9     5
# loc10    2
# loc11    0
# loc12    5
# dtype: int64

# %%
data.isna().sum().sum()  # всього порожніх значень після заміни
# Out:
# 38

# %%
data.notnull().sum().sum()  # всього не порожніх значень після заміни
# Out:
# 78468

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6539 entries, 1961-01-04 to 1978-12-31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   loc1    6539 non-null   float64
#  1   loc2    6539 non-null   float64
#  2   loc3    6539 non-null   float64
#  3   loc4    6539 non-null   float64
#  4   loc5    6539 non-null   float64
#  5   loc6    6539 non-null   float64
#  6   loc7    6539 non-null   float64
#  7   loc8    6539 non-null   float64
#  8   loc9    6539 non-null   float64
#  9   loc10   6539 non-null   float64
#  10  loc11   6539 non-null   float64
#  11  loc12   6539 non-null   float64
# dtypes: float64(12)
# memory usage: 664.1 KB

# %%
data.describe() # Середні швидкості вітру для всіх швидкостей вітру у всіх місцях та за весь час
                #мінімальна, максимальна та середня швидкість вітру та стандартні відхилення швидкості вітру в кожному місці за всі дні.
# Out:
#               loc1         loc2          loc3         loc4         loc5  \
# count  6539.000000  6539.000000  6.539000e+03  6539.000000  6539.000000
# mean     12.357281    10.639037  1.165450e+01     6.296273    10.448062
# std       5.618190     5.266726  5.010153e+00     3.600657     4.933565
# min       0.670000     0.210000  1.000000e-17     0.000000     0.130000
# 25%       8.120000     6.670000  7.960000e+00     3.580000     6.750000
# 50%      11.710000    10.130000  1.092000e+01     5.750000     9.960000
# 75%      15.920000    14.040000  1.467000e+01     8.380000    13.540000
# max      35.800000    33.370000  3.384000e+01    28.460000    37.540000
#
#               loc6         loc7         loc8          loc9        loc10  \
# count  6539.000000  6539.000000  6539.000000  6.539000e+03  6539.000000
# mean      7.083056     9.789681     8.482023  1.529286e+12     8.696067
# std       3.967672     4.980967     4.498777  1.236643e+14     4.500245
# ...

# %%
# TODO Find the average windspeed in January for each location

# %%
data.loc['1969-1':'1979-1':12].mean()
# Out:
# loc1     12.314704
# loc2     10.284046
# loc3     11.119211
# loc4      5.589868
# loc5      9.632039
# loc6      6.641579
# loc7      9.088885
# loc8      7.996184
# loc9      8.432072
# loc10     7.962697
# loc11    13.120461
# loc12    15.681612
# dtype: float64

# %%
# TODO Downsample the record to a yearly frequency for each location

# %%
data.resample('Y').mean()
# Out:
#                  loc1       loc2       loc3      loc4       loc5      loc6  \
# Date
# 1961-12-31  12.151864  10.154112  11.215651  6.784231  10.711982  7.586538
# 1962-12-31  12.274779  10.150856  11.714365  6.964337  10.692265  7.415331
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %%
# TODO Downsample the record to a monthly frequency for each location

# %%
data.resample('M').mean()
# Out:
#                  loc1       loc2       loc3      loc4       loc5       loc6  \
# Date
# 1961-01-31  13.354000  11.679000  11.534000  6.283000   9.803000   6.962000
# 1961-02-28  16.158000  14.850800  14.272400  8.998800  13.684000  10.735200
# 1961-03-31  10.660000  11.097407  10.420000  7.100741  10.265556   8.580000
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31  10.024643   8.495714  10.539286  5.992500   9.480357   6.633929
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  15.193846  13.518462  13.178974  6.747949  10.729487   7.887692
# 1978-12-31  16.742250  13.925500  15.323250  7.552750  12.120750   9.282250
#
# ...

# %%
# TODO Downsample the record to a weekly frequency for each location

# %%
data.resample('W').mean()
# Out:
#                  loc1       loc2       loc3      loc4       loc5       loc6  \
# Date
# 1961-01-08  12.316000  10.408000  10.050000  5.658000   8.506000   6.242000
# 1961-01-15  12.975000  10.975000  14.750000  6.540000  10.040000   6.665000
# 1961-01-22   9.590000  11.830000   7.960000  1.580000   7.920000   5.000000
# 1961-01-29        NaN        NaN        NaN       NaN        NaN        NaN
# 1961-02-05  16.827143  15.460000  12.618571  8.247143  13.361429   9.107143
# ...               ...        ...        ...       ...        ...        ...
# 1978-12-03  15.695000  12.454000  13.829000  6.538000  11.677000   9.042000
# 1978-12-10  20.078462  16.865385  15.906154  9.553077  14.863077  11.086923
# 1978-12-17  16.758571  14.692857  14.987143  6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857  4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714  6.507143   9.660000   8.620000
#
# ...
